# %%
import pandas as pd

# %%
df_criteo18 = pd.read_pickle('/mnt/mp_large_data/t.higuchi_large_data/opt/data/criteo_2018')

# %%
df_criteo18.head()
# Out:
#             md_id  day_of_week                             ac_id ac_name  \
# rp_date
# 2018-02-19      4            1  4efc7e117edf0cc00852f712c64f3784
# 2018-02-11      4            7  4efc7e117edf0cc00852f712c64f3784
# 2018-02-09      4            5  4efc7e117edf0cc00852f712c64f3784
# 2018-02-24      4            6  4efc7e117edf0cc00852f712c64f3784
# 2018-02-12      4            1  4efc7e117edf0cc00852f712c64f3784
#
#                cp_id cp_name  ag_id ag_name ad_id ad_name  ...  \
# rp_date                                                    ...
# 2018-02-19  100956.0           -9.0          None          ...
# 2018-02-11  100956.0           -9.0          None          ...
# 2018-02-09  100956.0           -9.0          None          ...
# 2018-02-24  100956.0           -9.0          None          ...
# 2018-02-12  100956.0           -9.0          None          ...
#
#                                        path1  \
# rp_date
# 2018-02-19  d41d8cd98f00b204e9800998ecf8427e
# ...

# %%
df_criteo18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1082337 entries, 2018-02-19 to 2018-07-03
# Data columns (total 68 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   md_id              1082337 non-null  int64
#  1   day_of_week        1082337 non-null  int64
#  2   ac_id              1082337 non-null  object
#  3   ac_name            1082337 non-null  object
#  4   cp_id              1082337 non-null  float64
#  5   cp_name            1082337 non-null  object
#  6   ag_id              1082337 non-null  float64
#  7   ag_name            1082337 non-null  object
#  8   ad_id              0 non-null        object
#  9   ad_name            1082337 non-null  object
#  10  ad_status          1082337 non-null  object
#  11  ad_title           1082337 non-null  object
#  12  ad_type            1082337 non-null  object
#  13  desc1              1082337 non-null  object
#  14  desc2              1082337 non-null  object
# ...
